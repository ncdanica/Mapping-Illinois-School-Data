# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Coding Class 1/FlorenceN.csv')

# %%
df
# Out:
#     Zymotic diseases_y    trace3_y    x  Wounds & injuries_y   trace4_y  \
# 0                    1  1854-04-01    0                    5        NaN
# 1                   12  1854-05-01    0                    9        NaN
# 2                   11  1854-06-01    0                    6        NaN
# 3                  359  1854-07-01    0                   23        NaN
# 4                  828  1854-08-01    1                   30        NaN
# 5                  788  1854-09-01   81                   70        NaN
# 6                  503  1854-10-01  132                  128        NaN
# 7                  844  1854-11-01  287                  106        NaN
# 8                 1725  1854-12-01  114                  131        NaN
# 9                 2761  1855-01-01   83                  324        NaN
# 10                2120  1855-02-01   42                  361        NaN
# 11                1205  1855-03-01   32                  172        NaN
# ...
